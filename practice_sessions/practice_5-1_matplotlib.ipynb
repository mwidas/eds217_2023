# %% [markdown]
# | [⬅️ Previous Session](practice_4-1_pandas.ipynb) | [🏠 Course Home](../index.ipynb)
#
# # Session 5-1: Matplotlib 📈
#
# ![mpl](./assets/mpl.png)
#
#
#
# **Don't forget to start your notebook with a cell containing the import statements you need for the session.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## 📚  <b> Practice 1. </b>
# Recreate the plot below. You do not need to match the colors exactly, but do not rely on <span class="codeb">matplotlib</span> defaults. Note: do not worry about the equation(s); these are included to indicate which functions to plot.
#
# <img src="./assets/mpl_prac1.png" alt="prac1" width="600"/>

# %%
# Generate a 1D array with 100 points between -5 and 5
x = np.linspace(1,100,100)
# Generate log wave
ylog = np.log(x)
plt.plot(x,ylog, color='lightseagreen')
plt.text(80, 3, 'y=log(x)', fontsize=12, color='lightseagreen')
# Out:
# Text(80, 3, 'y=log(x)')

# %% [markdown]
# ## 📚  <b> Practice 2. </b>
# Recreate the plot below. You do not need to match the colors exactly, but do not rely on <span class="codeb">matplotlib</span> defaults. Note: do not worry about the equation(s); these are included to indicate which functions to plot.
#
# <img src="./assets/mpl_prac2.png" alt="prac2" width="600"/>

# %%
 # Amplitude
x = np.linspace(0, 10, 100)  # Define the range of x values from 0 to 1
y = 1 * x * np.sin(2 * np.pi * x)  # Compute the corresponding y values
y1 = 10 * x * np.sin(2 * np.pi * x)  # Compute the corresponding y values
y2 = 5 * x * np.sin(2 * np.pi * x)  # Compute the corresponding y values

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the function and indicate what I want to plot lines to look like
ax.plot(x, y, color='cornflowerblue', marker='.', label='A=1')
ax.plot(x, y1, color='mediumturquoise', marker='*', linestyle='dashed', label='A=10')
ax.plot(x, y2, color='red', marker='^', linestyle='dashed', label='A=5')

# Add labels and a legend

ax.legend()

#Add limits

plt.xlim(0,10)
plt.ylim(-100,100)

# Show the plot
plt.show()

# %% [markdown]
# ## 📚  <b> Practice 3. </b>
#
# Import the data from `./data/BSRN_data.csv` and plot the temperature and relative humidity over the month of October 2019 at the BSRN station. Be sure to format the timestamps and include axis labels, a title, and a legend, if necessary.

# %%
bsrn = pd.read_csv('../data/BSRN_GOB_2019-10.csv',index_col=0,parse_dates=True)
bsrn.head()
# Out:
#                      H_m  SWD_Wm2  STD_SWD  DIR_Wm2  STD_DIR  DIF_Wm2
# DATE
# 2019-10-01 00:00:00    2     -3.0      0.0      0.0      0.0     -3.0  \
# 2019-10-01 00:01:00    2     -3.0      0.0      0.0      0.0     -3.0
# 2019-10-01 00:02:00    2     -3.0      0.0      0.0      0.0     -3.0
# 2019-10-01 00:03:00    2     -3.0      0.0      0.0      0.0     -3.0
# 2019-10-01 00:04:00    2     -3.0      0.0      0.0      0.0     -3.0
#
#                      STD_DIF  LWD_Wm2  STD_LWD  SWU_Wm2  LWU_Wm2  T_degC
# DATE
# 2019-10-01 00:00:00      0.0    300.0      0.1        0      383    16.2  \
# 2019-10-01 00:01:00      0.0    300.0      0.3        0      383    16.4
# 2019-10-01 00:02:00      0.0    300.0      0.2        0      383    16.5
# 2019-10-01 00:03:00      0.0    300.0      0.1        0      383    16.5
# 2019-10-01 00:04:00      0.0    300.0      0.1        0      383    16.8
#
#                        RH  P_hPa
# DATE
# 2019-10-01 00:00:00  30.7    966
# 2019-10-01 00:01:00  30.7    966
# 2019-10-01 00:02:00  30.5    966
# 2019-10-01 00:03:00  30.4    966
# 2019-10-01 00:04:00  30.5    966

# %%
fig, ax = plt.subplots(figsize=(8,6))

# Plot incoming SW radiation
ax.plot(bsrn.index,bsrn.RH)
ax.plot(bsrn.index,bsrn.T_degC)

# Label y-axis


# Format timestamps
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b-%y'))

# Format and rotate ticks
plt.setp(ax.get_xticklabels(), rotation=45, fontsize=10, ha='right')
ax.get_xticklabels()

#add legend
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 📚 Practice 4.
#
# Saturation vapor pressure, \( $ e^*(T_a) $ \), is the maximum pressure of water vapor that can exist in equilibrium above a flat plane of water at a given temperature. It can be calculated from the Tetens equation:
#
# $$ e^{*}(T_{a}) = a \times exp({\frac{b \cdot T_{a}}{T_{a} + c}}) $$
#
# where $ T_a $ is the air temperature in °C, $ a = 0.611  $ kPa,  $ b = 17.502  $, and  $ c = 240.97 °C  $.
#
# 1. Calculate \( $ e^*(T_a) $ \) in kPa for all temperatures in `bsrn`.
# 1. Plot temperature vs. saturation vapor pressure for the BSRN station. Be sure to format your plot appropriately and include axis labels, a title, and a legend, if necessary.
# 1. Compare your plot to Figure 3-1 in Campbell and Norman (1998), included below. Do they look more or less the same?
#
# ![cn](./assets/campbell_norman_fig3-1.png)

# %%
bsrn['SVP'] = 0.611 * (np.exp((17.52 * bsrn['T_degC'])/(bsrn['T_degC'] + 240.97)))
bsrn.head()


plt.plot(bsrn['T_degC'], bsrn['SVP'], color='k')

#Add limits

plt.xlim(0,40)
plt.ylim(0,8)

# Set axis labels
plt.xlabel(r'Temperature (C)')
plt.ylabel(r'Vapor Pressure (kPa)')

# Set title
txt = ('Figure 3-1. Saturation vapor pressure of air as a function of temperature.')
plt.figtext(0, -0.1, txt, fontsize = 15)


# Show the plot
plt.show()

# %% [markdown]
# ## 📚  <b> Practice 5. </b>
# The difference between saturation vapor pressure and ambient air pressure is called vapor pressure deficit, $\textit{VPD}$. $\textit{VPD}$ can be calculated from saturation vapor pressure and relative humidity, $h_r$, as follows:
# $$ \textit{VPD} \, = \, e^*(T_a) \cdot (1 \, - \, h_r)$$
# where $h_r$ is expressed as a fraction.
#
# 1. Calculate the vapor pressure deficit for the BSRN data.
# 1. Calculate the mean hourly $RH$ and $\textit{VPD}$ over the entire month.
# 1. Plot $RH$ and $\textit{VPD}$ as a function of time of day. (for extra python points, try plotting both variables on one plot using [ax.twinx()](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/two_scales.html))
# 1. How does relative humidity vary throughout the day? Why?
# 1. Compare your plot(s) to Figure 3-3 in Campbell and Norman (1998). How do the values of $e^*(T_a)$ and $\textit{VPD}$ for the BSRN station compare to those at constant vapor pressure in Figure 3-3?
#
# ![cn](./assets/campbell_norman_fig3-3.png)

# %%
bsrn['VPD'] = (bsrn['SVP'] * (1 - (bsrn['RH']/100)))
bsrn.head()

hourly_means = []

# Loop through unique hours
for hour in bsrn.index.hour.unique():
    # Filter data for the current hour
    data_for_hour = bsrn[bsrn.index.hour == hour]
    
    # Calculate mean for 'RH' and 'VPD'
    avg_RH = data_for_hour['RH'].mean()
    avg_VPD = data_for_hour['VPD'].mean()
    
    # Append the current hour and these two values to our list of hourly values:
    hourly_means.append([hour, avg_RH, avg_VPD])

# Create a DataFrame from the list of hourly means
hourly = pd.DataFrame(hourly_means, columns=['hour', 'avg_RH', 'avg_VPD'])

print(hourly)
# Out:
#     hour     avg_RH   avg_VPD
# 0      0  57.597742  0.914311
# 1      1  60.316505  0.824228
# 2      2  63.169946  0.749023
# 3      3  65.201720  0.692860
# 4      4  66.796290  0.629130
# 5      5  63.951290  0.714595
# 6      6  56.088495  0.966881
# 7      7  45.279624  1.432892
# 8      8  34.377043  2.036633
# 9      9  25.648226  2.743971
# 10    10  19.727903  3.405525
# 11    11  17.133548  3.834130
# 12    12  16.754194  3.979551
# 13    13  18.029624  3.861331
# 14    14  18.204462  3.732630
# 15    15  19.198387  3.473566
# 16    16  21.635484  3.113581
# 17    17  25.137419  2.721007
# 18    18  29.289892  2.393745
# 19    19  33.983495  2.079586
# 20    20  40.911559  1.680072
# 21    21  46.130323  1.404804
# 22    22  50.855430  1.194288
# 23    23  54.666774  1.043815

# %% [markdown]
# <hr style="border-top: 1px solid gray; margin-top: 24px; margin-bottom: 1px"></hr>
